# %%
import numpy as np
import requests
from dotenv import load_dotenv
import os
import json
import numpy as np
from scipy.stats import norm
import cryptocompare
from constant import RISK_FREE_RATE
import time
from calendar import timegm

# Load in environment variables and assign to variables
load_dotenv()
APIKEY = os.getenv('API_KEY')

# %%
# Testing API KEY
url = "https://api.ledgerx.com/trading/contracts/traded"

headers = {
    "Accept": "application/json",
    "Authorization": "JWT " + APIKEY
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"data":[{"id":22243883,"label":"ETH-29JUL2022-1250-Call","date_expires":"2022-07-29 20:00:00+0000"},{"id":22241085,"label":"ETH-24JUN2022-3500-Call","date_expires":"2022-06-24 20:00:00+0000"},{"id":22241083,"label":"ETH-24JUN2022-2500-Call","date_expires":"2022-06-24 20:00:00+0000"},{"id":22238181,"label":"ETH-27MAY2022-3000-Call","date_expires":"2022-05-27 20:00:00+0000"}],"meta":{"total_count":4,"next":null,"previous":null,"limit":1000,"offset":0}}

# %%
# Testing the function to get price for a given crypto

jsonprice = cryptocompare.get_price('ETH', currency='USD', full=False)
price = jsonprice['ETH']['USD']
print(jsonprice)
print(price)
# Out:
# {'ETH': {'USD': 1084.66}}
# 1084.66

# %%
# Defining Contract class

class Contract:

  # Black Scholes models for calls and puts
  def BS_CALL(self, S, K, T, r, sigma):
    N = norm.cdf
    d1 = (np.log(S/K) + (r + sigma**2/2)*T) / (sigma*np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    return S * N(d1) - K * np.exp(-r*T)* N(d2)

  def BS_PUT(self,S, K, T, r, sigma):
    N = norm.cdf
    d1 = (np.log(S/K) + (r + sigma**2/2)*T) / (sigma*np.sqrt(T))
    d2 = d1 - sigma* np.sqrt(T)
    return K*np.exp(-r*T)*N(-d2) - S*N(-d1)

  # CONSTRUCTOR
  def __init__(self, id, strike, expiration, type):
    self.id = id
    self.strike = strike / 100
    self.expiration = expiration
    self.type = type
    self.BS_Price = None

    # Run Black Scholes model

    if (self.type == "call"):
      
      # Current underlying Eth price
      jsonunderlyingPrice = cryptocompare.get_price('ETH', currency='USD', full=False)
      underlyingPrice = jsonunderlyingPrice['ETH']['USD']

      # calculation for the days until expiration
      currentUTCTimeUnix = time.time()

      # date formatting
      formattedExpirationDate = time.strptime(self.expiration, "%Y-%m-%d %H:%M:%S%z")
      expirationTimeUnix = timegm(formattedExpirationDate)

      timeToExpirationSeconds = expirationTimeUnix - currentUTCTimeUnix
      daysToExpiration = float (timeToExpirationSeconds / float(86400.0))
      yearsToExpiration = float (daysToExpiration/ 365.0)

      # Now I just have to find a way to calculate implied volatility . . . 

      # For now I will just choose some random I.V . . . say 85%

      # TODO.  FIND SOME WAY TO ESTIMATE THIS
      impliedVol = 0.85


      self.BS_Price = self.BS_CALL(underlyingPrice, self.strike, yearsToExpiration, RISK_FREE_RATE, impliedVol)
    elif (self.type == "put"):
      self.BS_Price = self.BS_PUT()
    else:
      print("Shouldn't get here!")

# %%
# testing time conversions

testexpiration = "2023-06-30 20:00:00+0000"
formattedExpirationDate = time.strptime(testexpiration, "%Y-%m-%d %H:%M:%S%z")
expirationTimeUnix = timegm(formattedExpirationDate)

print((expirationTimeUnix - time.time())/86400)
daystoExpiration = (expirationTimeUnix - time.time())/86400
print("years to expiration %d:", daystoExpiration/365.0)
# Out:
# 351.9305517224885
# years to expiration %d: 0.964193292388822

# %%
# testing contract struct

testContract = Contract("22245263", 150000, "2023-06-30 20:00:00+0000", "call")

# %%
# Make a request for the contracts that are: active, calls, options, and ETH

url = "https://api.ledgerx.com/trading/contracts?active=true&contract_type=call&derivative_type=options_contract&asset=ETH"

headers = {"Accept": "application/json"}

response = requests.get(url, headers=headers)

decodedMessage = json.loads(response.text)

messageData = decodedMessage['data']

messageMeta = decodedMessage['meta']

print(messageData[0])

totalContracts = messageMeta['total_count']

# Creating a list of Contract objects
contractTest = Contract(messageData[0]['id'], messageData[0]['strike_price'], messageData[0]['date_expires'], messageData[0]['type'])

contractList = []
for i in range (0,totalContracts):
    contract = Contract(messageData[i]['id'], messageData[i]['strike_price'], messageData[i]['date_expires'], messageData[i]['type'])
    contractList.append(contract)
# Out:
# <class 'int'>
# 150000
# <class 'str'>
# call
# 2023-06-30 20:00:00+0000
# 2023-06-30 20:00:00+0000
# 2023-06-30 20:00:00+0000
# 2023-06-30 20:00:00+0000
# 2023-06-30 20:00:00+0000
# 2023-06-30 20:00:00+0000
# 2023-06-30 20:00:00+0000
# 2023-06-30 20:00:00+0000
# 2023-06-30 20:00:00+0000
# 2023-03-31 20:00:00+0000
# 2023-03-31 20:00:00+0000
# 2023-03-31 20:00:00+0000
# 2023-03-31 20:00:00+0000
# 2023-03-31 20:00:00+0000
# 2023-03-31 20:00:00+0000
# 2023-03-31 20:00:00+0000
# 2023-03-31 20:00:00+0000
# 2023-03-31 20:00:00+0000
# 2022-12-30 21:00:00+0000
# 2022-12-30 21:00:00+0000
# 2022-12-30 21:00:00+0000
# 2022-12-30 21:00:00+0000
# 2022-12-30 21:00:00+0000
# 2022-12-30 21:00:00+0000
# 2022-12-30 21:00:00+0000
# 2022-12-30 21:00:00+0000
# 2022-12-30 21:00:00+0000
# 2022-12-30 21:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-09-30 20:00:00+0000
# 2022-08-26 20:00:00+0000
# 2022-08-26 20:00:00+0000
# 2022-08-26 20:00:00+0000
# 2022-08-26 20:00:00+0000
# 2022-08-26 20:00:00+0000
# 2022-08-26 20:00:00+0000
# 2022-08-26 20:00:00+0000
# 2022-08-26 20:00:00+0000
# 2022-08-26 20:00:00+0000
# 2022-08-26 20:00:00+0000
# 2022-07-29 20:00:00+0000
# 2022-07-29 20:00:00+0000
# 2022-07-29 20:00:00+0000
# 2022-07-29 20:00:00+0000
# 2022-07-29 20:00:00+0000
# 2022-07-29 20:00:00+0000
# 2022-07-29 20:00:00+0000
# 2022-07-29 20:00:00+0000
# 2022-07-29 20:00:00+0000
# 2022-07-29 20:00:00+0000
# 2022-07-29 20:00:00+0000
# 2022-07-29 20:00:00+0000

# %%
import websocket
import _thread
import time
import rel




def on_message(ws, message):
     print("JSON MESSAGE FOR YA")
     decodedmessage = json.loads(message)
     mestype = (decodedmessage['type'])
     



def on_error(ws, error):
    print(error)

def on_close(ws, close_status_code, close_msg):
    print("### closed ###")

def on_open(ws):
    print("Opened connection")

if __name__ == "__main__":
    websocket.enableTrace(True)
    ws = websocket.WebSocketApp("wss://api.ledgerx.com/ws?token=" + APIKEY,
                              on_open=on_open,
                              on_message=on_message,
                              on_error=on_error,
                              on_close=on_close)

    ws.run_forever(dispatcher=rel)  # Set dispatcher to automatic reconnection
    rel.signal(2, rel.abort)  # Keyboard Interrupt
    rel.dispatch()
# Out:
# --- request header ---
# GET /ws?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..UJOKelJvInGLPeleC08b54oWMC33GmwrKvAQ2Fc2KMIHIaeeMtdrw2SXRi1JNy8IHNkxtmLwMx1i1Kdg89bwSg HTTP/1.1
# Upgrade: websocket
# Host: api.ledgerx.com
# Origin: https://api.ledgerx.com
# Sec-WebSocket-Key: 7QSa+rkNzZvP36vhGagVsw==
# Sec-WebSocket-Version: 13
# Connection: Upgrade
#
#
# -----------------------
# --- response header ---
# HTTP/1.1 101 Switching Protocols
# Date: Wed, 13 Jul 2022 19:27:35 GMT
# Connection: upgrade
# Upgrade: WebSocket
# Sec-WebSocket-Accept: w0jah6XHoz3Y0OvIt7MSf6Pa1m4=
# CF-Cache-Status: DYNAMIC
# Expect-CT: max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"
# Strict-Transport-Security: max-age=0; includeSubDomains; preload
# X-Content-Type-Options: nosniff
# Server: cloudflare
# CF-RAY: 72a46ab8481e2c48-ORD
# -----------------------
# ++Rcv raw: b'\x81\x18{"type": "auth_success"}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"type": "auth_success"}'
# ++Rcv raw: b'\x81B{"session_id": "83adbd125f544970b79c6f998caa7e3f", "type": "meta"}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"session_id": "83adbd125f544970b79c6f998caa7e3f", "type": "meta"}'
# ++Rcv raw: b'\x81x{"type": "state_manifest", "state_manifest": {"manifest_id": "83adbd125f544970b79c6f998caa7e3f", "open_order_count": 1}}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"type": "state_manifest", "state_manifest": {"manifest_id": "83adbd125f544970b79c6f998caa7e3f", "open_order_count": 1}}'
# ++Rcv raw: b'\x81~\x01\xd2{"collateral": {"available_balances": {"BTC": 0, "CBTC": 0, "ETH": 111107720, "USD": 598}, "deliverable_locked_balances": {"BTC": 0, "CBTC": 0, "ETH": 0, "USD": 0}, "fee_locked_balances": {"BTC": 0, "CBTC": 0, "ETH": 0, "USD": 0}, "order_locked_balances": {"BTC": 0, "CBTC": 0, "ETH": 0, "USD": 0}, "position_locked_balances": {"BTC": 0, "CBTC": 0, "ETH": 100000000, "USD": 0}}, "manifest_id": "83adbd125f544970b79c6f998caa7e3f", "type": "collateral_balance_update"}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{
"inserted_price": 0}'
# ++Rcv raw: b'\x81~\x025{"status_type": 200, "open_interest": 596, "filled_size": 0, "is_volatile": true, "clock": 30828, "original_size": 2, "price": 170, "vwap": 0, "type": "action_report", "original_price": 170, "ticks": 1657740456171293263, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22243085, "inserted_time": 1657731347326731011, "updated_time": 1657740456171293262, "inserted_size": 2, "status_reason": 0, "mid": "19e7732aced54f8594bb71674a6734d5", "size": 2, "timestamp": 1657740456171293262, "is_ask": false, "inserted_price": 170}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 200, "open_interest": 596, "filled_size": 0, "is_volatile": true, "clock": 30828, "original_size": 2, "price": 170, "vwap": 0, "type": "action_report", "original_price": 170, "ticks": 1657740456171293263, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22243085, "inserted_time": 1657731347326731011, "updated_time": 1657740456171293262, "inserted_size": 2, "status_reason": 0, "mid": "19e7732aced54f8594bb71674a6734d5", "size": 2, "timestamp": 1657740456171293262, "is_ask": false, "inserted_price": 170}'
# ++Rcv raw: b'\x81~\x00\x93{"bid": 1939100, "ask_size": 25, "bid_size": 25, "type": "book_top", "clock": 1519795, "contract_type": 8, "ask": 2007900, "contract_id": 22244813}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 1939100, "ask_size": 25, "bid_size": 25, "type": "book_top", "clock": 1519795, "contract_type": 8, "ask": 2007900, "contract_id": 22244813}'
# ++Rcv raw: b'\x81~\x025{"status_type": 203, "open_interest": 19, "filled_size": 0, "is_volatile": true, "clock": 1519794, "original_size": 2, "price": 0, "vwap": 0, "type": "action_report", "original_price": 2023100, "ticks": 1657740456181842577, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 2, "contract_id": 22244813, "inserted_time": 1657740029617985440, "updated_time": 1657740456181842577, "inserted_size": 0, "status_reason": 0, "mid": "da7f4433cbd64afbbc3406f7a2d8203f", "size": 0, "timestamp": 1657740456181842577, "is_ask": true, "inserted_price": 0}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 203, "open_interest": 19, "filled_size": 0, "is_volatile": true, "clock": 1519794, "original_size": 2, "price": 0, "vwap": 0, "type": "action_report", "original_price": 2023100, "ticks": 1657740456181842577, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 2, "contract_id": 22244813, "inserted_time": 1657740029617985440, "updated_time": 1657740456181842577, "inserted_size": 0, "status_reason": 0, "mid": "da7f4433cbd64afbbc3406f7a2d8203f", "size": 0, "timestamp": 1657740456181842577, "is_ask": true, "inserted_price": 0}'
# ++Rcv raw: b'\x81~\x02A{"status_type": 200, "open_interest": 19, "filled_size": 0, "is_volatile": true, "clock": 1519795, "original_size": 2, "price": 2022500, "vwap": 0, "type": "action_report", "original_price": 2022500, "ticks": 1657740456181842578, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22244813, "inserted_time": 1657740029617985440, "updated_time": 1657740456181842577, "inserted_size": 2, "status_reason": 0, "mid": "da7f4433cbd64afbbc3406f7a2d8203f", "size": 2, "timestamp": 1657740456181842577, "is_ask": true, "inserted_price": 2022500}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 200, "open_interest": 19, "filled_size": 0, "is_volatile": true, "clock": 1519795, "original_size": 2, "price": 2022500, "vwap": 0, "type": "action_report", "original_price": 2022500, "ticks": 1657740456181842578, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22244813, "inserted_time": 1657740029617985440, "updated_time": 1657740456181842577, "inserted_size": 2, "status_reason": 0, "mid": "da7f4433cbd64afbbc3406f7a2d8203f", "size": 2, "timestamp": 1657740456181842577, "is_ask": true, "inserted_price": 2022500}'
# ++Rcv raw: b'\x81~\x00\x94{"bid": 1966500, "ask_size": 100, "bid_size": 97, "type": "book_top", "clock": 1124517, "contract_type": 2, "ask": 1977200, "contract_id": 22244182}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 1966500, "ask_size": 100, "bid_size": 97, "type": "book_top", "clock": 1124517, "contract_type": 2, "ask": 1977200, "contract_id": 22244182}'
# ++Rcv raw: b'\x81~\x02:{"status_type": 203, "open_interest": 582, "filled_size": 0, "is_volatile": true, "clock": 1124516, "original_size": 100, "price": 0, "vwap": 0, "type": "action_report", "original_price": 1982600, "ticks": 1657740456184067475, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 100, "contract_id": 22244182, "inserted_time": 1657740028093008197, "updated_time": 1657740456184067475, "inserted_size": 0, "status_reason": 0, "mid": "afaf2ae20a0e4e7f8a8f694af3980e02", "size": 0, "timestamp": 1657740456184067475, "is_ask": true, "inserted_price": 0}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 203, "open_interest": 582, "filled_size": 0, "is_volatile": true, "clock": 1124516, "original_size": 100, "price": 0, "vwap": 0, "type": "action_report", "original_price": 1982600, "ticks": 1657740456184067475, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 100, "contract_id": 22244182, "inserted_time": 1657740028093008197, "updated_time": 1657740456184067475, "inserted_size": 0, "status_reason": 0, "mid": "afaf2ae20a0e4e7f8a8f694af3980e02", "size": 0, "timestamp": 1657740456184067475, "is_ask": true, "inserted_price": 0}'
# ++Rcv raw: b'\x81~\x02H{"status_type": 200, "open_interest": 582, "filled_size": 0, "is_volatile": true, "clock": 1124517, "original_size": 100, "price": 1982000, "vwap": 0, "type": "action_report", "original_price": 1982000, "ticks": 1657740456184067476, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22244182, "inserted_time": 1657740028093008197, "updated_time": 1657740456184067475, "inserted_size": 100, "status_reason": 0, "mid": "afaf2ae20a0e4e7f8a8f694af3980e02", "size": 100, "timestamp": 1657740456184067475, "is_ask": true, "inserted_price": 1982000}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 200, "open_interest": 582, "filled_size": 0, "is_volatile": true, "clock": 1124517, "original_size": 100, "price": 1982000, "vwap": 0, "type": "action_report", "original_price": 1982000, "ticks": 1657740456184067476, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22244182, "inserted_time": 1657740028093008197, "updated_time": 1657740456184067475, "inserted_size": 100, "status_reason": 0, "mid": "afaf2ae20a0e4e7f8a8f694af3980e02", "size": 100, "timestamp": 1657740456184067475, "is_ask": true, "inserted_price": 1982000}'
# ++Rcv raw: b'\x81~\x00\x93{"bid": 1939400, "ask_size": 10, "bid_size": 25, "type": "book_top", "clock": 1504092, "contract_type": 8, "ask": 2003500, "contract_id": 22242758}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 1939400, "ask_size": 10, "bid_size": 25, "type": "book_top", "clock": 1504092, "contract_type": 8, "ask": 2003500, "contract_id": 22242758}'
# ++Rcv raw: b'\x81~\x025{"status_type": 203, "open_interest": 38, "filled_size": 0, "is_volatile": true, "clock": 1504091, "original_size": 2, "price": 0, "vwap": 0, "type": "action_report", "original_price": 2023100, "ticks": 1657740456191716188, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 2, "contract_id": 22242758, "inserted_time": 1657740028073052402, "updated_time": 1657740456191716188, "inserted_size": 0, "status_reason": 0, "mid": "fd11796ac05d4802ae79d19d5f00cd63", "size": 0, "timestamp": 1657740456191716188, "is_ask": true, "inserted_price": 0}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 203, "open_interest": 38, "filled_size": 0, "is_volatile": true, "clock": 1504091, "original_size": 2, "price": 0, "vwap": 0, "type": "action_report", "original_price": 2023100, "ticks": 1657740456191716188, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size":
"filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22244147, "inserted_time": 1657740028297010851, "updated_time": 1657740456276288698, "inserted_size": 1, "status_reason": 0, "mid": "c8fed09ced504207aec36237f71f754d", "size": 1, "timestamp": 1657740456276288698, "is_ask": false, "inserted_price": 36600}'
# ++Rcv raw: b'\x81~\x00\x88{"bid": 10, "ask_size": 1, "bid_size": 500, "type": "book_top", "clock": 45608, "contract_type": 1, "ask": 100, "contract_id": 22243087}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 10, "ask_size": 1, "bid_size": 500, "type": "book_top", "clock": 45608, "contract_type": 1, "ask": 100, "contract_id": 22243087}'
# ++Rcv raw: b'\x81~\x02/{"status_type": 203, "open_interest": 22, "filled_size": 0, "is_volatile": true, "clock": 45607, "original_size": 1, "price": 0, "vwap": 0, "type": "action_report", "original_price": 100, "ticks": 1657740456301123367, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 1, "contract_id": 22243087, "inserted_time": 1657731347483918419, "updated_time": 1657740456301123367, "inserted_size": 0, "status_reason": 0, "mid": "b6989821755c479884c4cd75f174aabc", "size": 0, "timestamp": 1657740456301123367, "is_ask": true, "inserted_price": 0}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 203, "open_interest": 22, "filled_size": 0, "is_volatile": true, "clock": 45607, "original_size": 1, "price": 0, "vwap": 0, "type": "action_report", "original_price": 100, "ticks": 1657740456301123367, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 1, "contract_id": 22243087, "inserted_time": 1657731347483918419, "updated_time": 1657740456301123367, "inserted_size": 0, "status_reason": 0, "mid": "b6989821755c479884c4cd75f174aabc", "size": 0, "timestamp": 1657740456301123367, "is_ask": true, "inserted_price": 0}'
# ++Rcv raw: b'\x81~\x023{"status_type": 200, "open_interest": 22, "filled_size": 0, "is_volatile": true, "clock": 45608, "original_size": 1, "price": 100, "vwap": 0, "type": "action_report", "original_price": 100, "ticks": 1657740456301123368, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22243087, "inserted_time": 1657731347483918419, "updated_time": 1657740456301123367, "inserted_size": 1, "status_reason": 0, "mid": "b6989821755c479884c4cd75f174aabc", "size": 1, "timestamp": 1657740456301123367, "is_ask": true, "inserted_price": 100}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 200, "open_interest": 22, "filled_size": 0, "is_volatile": true, "clock": 45608, "original_size": 1, "price": 100, "vwap": 0, "type": "action_report", "original_price": 100, "ticks": 1657740456301123368, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22243087, "inserted_time": 1657731347483918419, "updated_time": 1657740456301123367, "inserted_size": 1, "status_reason": 0, "mid": "b6989821755c479884c4cd75f174aabc", "size": 1, "timestamp": 1657740456301123367, "is_ask": true, "inserted_price": 100}'
# ++Rcv raw: b'\x81~\x00~{"run_id": 1657570503975469568, "timestamp": 1657740456000000000, "interval_ms": 1000, "type": "heartbeat", "ticks": 30242257}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"run_id": 1657570503975469568, "timestamp": 1657740456000000000, "interval_ms": 1000, "type": "heartbeat", "ticks": 30242257}'
# ++Rcv raw: b'\x81~\x00\x86{"bid": 10, "ask_size": 4, "bid_size": 2, "type": "book_top", "clock": 25645, "contract_type": 1, "ask": 590, "contract_id": 22245234}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 10, "ask_size": 4, "bid_size": 2, "type": "book_top", "clock": 25645, "contract_type": 1, "ask": 590, "contract_id": 22245234}'
# ++Rcv raw: b'\x81~\x02/{"status_type": 203, "open_interest": 28, "filled_size": 0, "is_volatile": true, "clock": 25644, "original_size": 1, "price": 0, "vwap": 0, "type": "action_report", "original_price": 10, "ticks": 1657740456434972011, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 1, "contract_id": 22245234, "inserted_time": 1657731347628523706, "updated_time": 1657740456434972011, "inserted_size": 0, "status_reason": 0, "mid": "467f84a8b8b949348a4a4bcd4892adb4", "size": 0, "timestamp": 1657740456434972011, "is_ask": false, "inserted_price": 0}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 203, "open_interest": 28, "filled_size": 0, "is_volatile": true, "clock": 25644, "original_size": 1, "price": 0, "vwap": 0, "type": "action_report", "original_price": 10, "ticks": 1657740456434972011, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 1, "contract_id": 22245234, "inserted_time": 1657731347628523706, "updated_time": 1657740456434972011, "inserted_size": 0, "status_reason": 0, "mid": "467f84a8b8b949348a4a4bcd4892adb4", "size": 0, "timestamp": 1657740456434972011, "is_ask": false, "inserted_price": 0}'
# ++Rcv raw: b'\x81~\x021{"status_type": 200, "open_interest": 28, "filled_size": 0, "is_volatile": true, "clock": 25645, "original_size": 1, "price": 10, "vwap": 0, "type": "action_report", "original_price": 10, "ticks": 1657740456434972012, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22245234, "inserted_time": 1657731347628523706, "updated_time": 1657740456434972011, "inserted_size": 1, "status_reason": 0, "mid": "467f84a8b8b949348a4a4bcd4892adb4", "size": 1, "timestamp": 1657740456434972011, "is_ask": false, "inserted_price": 10}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 200, "open_interest": 28, "filled_size": 0, "is_volatile": true, "clock": 25645, "original_size": 1, "price": 10, "vwap": 0, "type": "action_report", "original_price": 10, "ticks": 1657740456434972012, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22245234, "inserted_time": 1657731347628523706, "updated_time": 1657740456434972011, "inserted_size": 1, "status_reason": 0, "mid": "467f84a8b8b949348a4a4bcd4892adb4", "size": 1, "timestamp": 1657740456434972011, "is_ask": false, "inserted_price": 10}'
# ++Rcv raw: b'\x81~\x00\x89{"bid": 900, "ask_size": 1, "bid_size": 9, "type": "book_top", "clock": 137391, "contract_type": 1, "ask": 8800, "contract_id": 22245674}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 900, "ask_size": 1, "bid_size": 9, "type": "book_top", "clock": 137391, "contract_type": 1, "ask": 8800, "contract_id": 22245674}'
# ++Rcv raw: b'\x81~\x024{"status_type": 203, "open_interest": 2, "filled_size": 0, "is_volatile": true, "clock": 137390, "original_size": 152, "price": 0, "vwap": 0, "type": "action_report", "original_price": 100, "ticks": 1657740456499197483, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 152, "contract_id": 22245674, "inserted_time": 1657730522390986276, "updated_time": 1657740456499197483, "inserted_size": 0, "status_reason": 0, "mid": "0702b77ba5e842f8abaec9d086e06bb8", "size": 0, "timestamp": 1657740456499197483, "is_ask": false, "inserted_price": 0}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 203, "open_interest": 2, "filled_size": 0, "is_volatile": true, "clock": 137390, "original_size": 152, "price": 0, "vwap": 0, "type": "action_report", "original_price": 100, "ticks": 1657740456499197483, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 152, "contract_id": 22245674, "inserted_time": 1657730522390986276, "updated_time": 1657740456499197483, "inserted_size": 0, "status_reason": 0, "mid": "0702b77ba5e842f8abaec9d086e06bb8", "size": 0, "timestamp": 1657740456499197483, "is_ask": false, "inserted_price": 0}'
# ++Rcv raw: b'\x81~\x02:{"status_type": 200, "open_interest": 2, "filled_size": 0, "is_volatile": true, "clock": 137391, "original_size": 152, "price": 100, "vwap": 0, "type": "action_report", "original_price": 100, "ticks": 1657740456499197484, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22245674, "inserted_time": 1657730522390986276, "updated_time": 1657740456499197483, "inserted_size": 152, "status_reason": 0, "mid": "0702b77ba5e842f8abaec9d086e06bb8", "size": 152, "timestamp": 1657740456499197483, "is_ask": false, "inserted_price": 100}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 200, "open_interest": 2, "filled_size": 0, "is_volatile": true, "clock": 137391, "original_size": 152, "price": 100, "vwap": 0, "type": "action_report", "original_price": 100, "ticks": 1657740456499197484, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22245674, "inserted_time": 1657730522390986276, "updated_time": 1657740456499197483, "inserted_size": 152, "status_reason": 0, "mid": "0702b77ba5e842f8abaec9d086e06bb8", "size": 152, "timestamp": 1657740456499197483, "is_ask": false, "inserted_price": 100}'
# ++Rcv raw: b'\x81~\x00\x88{"bid": 600, "ask_size": 3, "bid_size": 1, "type": "book_top", "clock": 23373, "contract_type": 1, "ask": 1490, "contract_id": 22243886}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 600, "ask_size": 3, "bid_size": 1, "type": "book_top", "clock": 23373, "contract_type": 1, "ask": 1490, "contract_id": 22243886}'
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# ++Rcv raw: b'\x81~\x022{"status_type": 203, "open_interest": 1527, "filled_size": 0, "is_volatile": true, "clock": 23372, "original_size": 2, "price": 0, "vwap": 0, "type": "action_report", "original_price": 380, "ticks": 1657740456581842390, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 2, "contract_id": 22243886, "inserted_time": 1657731347786392669, "updated_time": 1657740456581842390, "inserted_size": 0, "status_reason": 0, "mid": "c0004f17ba854253a04cdc41945b8cda", "size": 0, "timestamp": 1657740456581842390, "is_ask": false, "inserted_price": 0}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 203, "open_interest": 1527, "filled_size": 0, "is_volatile": true, "clock": 23372, "original_size": 2, "price": 0, "vwap": 0, "type": "action_report", "original_price": 380, "ticks": 1657740456581842390, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 2, "contract_id": 22243886, "inserted_time": 1657731347786392669, "updated_time": 1657740456581842390, "inserted_size": 0, "status_reason": 0, "mid": "c0004f17ba854253a04cdc41945b8cda", "size": 0, "timestamp": 1657740456581842390, "is_ask": false, "inserted_price": 0}'
# ...
# ++Rcv raw: b'\x81~\x00\x8e{"bid": 22200, "ask_size": 300, "bid_size": 2, "type": "book_top", "clock": 120520, "contract_type": 1, "ask": 29300, "contract_id": 22245677}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 22200, "ask_size": 300, "bid_size": 2, "type": "book_top", "clock": 120520, "contract_type": 1, "ask": 29300, "contract_id": 22245677}'
# ++Rcv raw: b'\x81~\x024{"status_type": 203, "open_interest": 2453, "filled_size": 0, "is_volatile": true, "clock": 120519, "original_size": 3, "price": 0, "vwap": 0, "type": "action_report", "original_price": 48400, "ticks": 1657740457289224670, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 3, "contract_id": 22245677, "inserted_time": 1657731348497851682, "updated_time": 1657740457289224670, "inserted_size": 0, "status_reason": 0, "mid": "398f3158996a4948aa74a477549a3baa", "size": 0, "timestamp": 1657740457289224670, "is_ask": true, "inserted_price": 0}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 203, "open_interest": 2453, "filled_size": 0, "is_volatile": true, "clock": 120519, "original_size": 3, "price": 0, "vwap": 0, "type": "action_report", "original_price": 48400, "ticks": 1657740457289224670, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 3, "contract_id": 22245677, "inserted_time": 1657731348497851682, "updated_time": 1657740457289224670, "inserted_size": 0, "status_reason": 0, "mid": "398f3158996a4948aa74a477549a3baa", "size": 0, "timestamp": 1657740457289224670, "is_ask": true, "inserted_price": 0}'
# ++Rcv raw: b'\x81~\x02<{"status_type": 200, "open_interest": 2453, "filled_size": 0, "is_volatile": true, "clock": 120520, "original_size": 3, "price": 48600, "vwap": 0, "type": "action_report", "original_price": 48600, "ticks": 1657740457289224671, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22245677, "inserted_time": 1657731348497851682, "updated_time": 1657740457289224670, "inserted_size": 3, "status_reason": 0, "mid": "398f3158996a4948aa74a477549a3baa", "size": 3, "timestamp": 1657740457289224670, "is_ask": true, "inserted_price": 48600}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 200, "open_interest": 2453, "filled_size": 0, "is_volatile": true, "clock": 120520, "original_size": 3, "price": 48600, "vwap": 0, "type": "action_report", "original_price": 48600, "ticks": 1657740457289224671, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22245677, "inserted_time": 1657731348497851682, "updated_time": 1657740457289224670, "inserted_size": 3, "status_reason": 0, "mid": "398f3158996a4948aa74a477549a3baa", "size": 3, "timestamp": 1657740457289224670, "is_ask": true, "inserted_price": 48600}'
# ++Rcv raw: b'\x81~\x00\x8b{"bid": 2100, "ask_size": 24, "bid_size": 5, "type": "book_top", "clock": 145071, "contract_type": 1, "ask": 3600, "contract_id": 22245679}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 2100, "ask_size": 24, "bid_size": 5, "type": "book_top", "clock": 145071, "contract_type": 1, "ask": 3600, "contract_id": 22245679}'
# ++Rcv raw: b'\x81~\x023{"status_type": 203, "open_interest": 1786, "filled_size": 0, "is_volatile": true, "clock": 145070, "original_size": 3, "price": 0, "vwap": 0, "type": "action_report", "original_price": 4800, "ticks": 1657740457420366041, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 3, "contract_id": 22245679, "inserted_time": 1657731348637421391, "updated_time": 1657740457420366041, "inserted_size": 0, "status_reason": 0, "mid": "62773b169e9c45afa7a7415b695916f1", "size": 0, "timestamp": 1657740457420366041, "is_ask": true, "inserted_price": 0}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 203, "open_interest": 1786, "filled_size": 0, "is_volatile": true, "clock": 145070, "original_size": 3, "price": 0, "vwap": 0, "type": "action_report", "original_price": 4800, "ticks": 1657740457420366041, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 3, "contract_id": 22245679, "inserted_time": 1657731348637421391, "updated_time": 1657740457420366041, "inserted_size": 0, "status_reason": 0, "mid": "62773b169e9c45afa7a7415b695916f1", "size": 0, "timestamp": 1657740457420366041, "is_ask": true, "inserted_price": 0}'
# ++Rcv raw: b'\x81~\x029{"status_type": 200, "open_interest": 1786, "filled_size": 0, "is_volatile": true, "clock": 145071, "original_size": 3, "price": 4900, "vwap": 0, "type": "action_report", "original_price": 4900, "ticks": 1657740457420366042, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22245679, "inserted_time": 1657731348637421391, "updated_time": 1657740457420366041, "inserted_size": 3, "status_reason": 0, "mid": "62773b169e9c45afa7a7415b695916f1", "size": 3, "timestamp": 1657740457420366041, "is_ask": true, "inserted_price": 4900}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 200, "open_interest": 1786, "filled_size": 0, "is_volatile": true, "clock": 145071, "original_size": 3, "price": 4900, "vwap": 0, "type": "action_report", "original_price": 4900, "ticks": 1657740457420366042, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22245679, "inserted_time": 1657731348637421391, "updated_time": 1657740457420366041, "inserted_size": 3, "status_reason": 0, "mid": "62773b169e9c45afa7a7415b695916f1", "size": 3, "timestamp": 1657740457420366041, "is_ask": true, "inserted_price": 4900}'
# ++Rcv raw: b'\x81~\x00~{"run_id": 1657570503975469568, "timestamp": 1657740457000000000, "interval_ms": 1000, "type": "heartbeat", "ticks": 30242258}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"run_id": 1657570503975469568, "timestamp": 1657740457000000000, "interval_ms": 1000, "type": "heartbeat", "ticks": 30242258}'
# ++Rcv raw: b'\x81~\x00\x89{"bid": 900, "ask_size": 1, "bid_size": 9, "type": "book_top", "clock": 137395, "contract_type": 1, "ask": 8800, "contract_id": 22245674}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 900, "ask_size": 1, "bid_size": 9, "type": "book_top", "clock": 137395, "contract_type": 1, "ask": 8800, "contract_id": 22245674}'
# ++Rcv raw: b'\x81~\x024{"status_type": 203, "open_interest": 2, "filled_size": 0, "is_volatile": true, "clock": 137394, "original_size": 152, "price": 0, "vwap": 0, "type": "action_report", "original_price": 100, "ticks": 1657740457495033378, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size":
'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 200, "open_interest": 427, "filled_size": 0, "is_volatile": true, "clock": 131071, "original_size": 152, "price": 354400, "vwap": 0, "type": "action_report", "original_price": 354400, "ticks": 1657740457508708628, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22245172, "inserted_time": 1657730522418806784, "updated_time": 1657740457508708627, "inserted_size": 152, "status_reason": 0, "mid": "bab1bbc0752845fb92b03702523612dd", "size": 152, "timestamp": 1657740457508708627, "is_ask": false, "inserted_price": 354400}'
# ++Rcv raw: b'\x81~\x00\x8f{"bid": 38100, "ask_size": 160, "bid_size": 24, "type": "book_top", "clock": 119342, "contract_type": 1, "ask": 65200, "contract_id": 22244140}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 38100, "ask_size": 160, "bid_size": 24, "type": "book_top", "clock": 119342, "contract_type": 1, "ask": 65200, "contract_id": 22244140}'
# ++Rcv raw: b'\x81~\x028{"status_type": 203, "open_interest": 835, "filled_size": 0, "is_volatile": true, "clock": 119341, "original_size": 152, "price": 0, "vwap": 0, "type": "action_report", "original_price": 38100, "ticks": 1657740457514039961, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 152, "contract_id": 22244140, "inserted_time": 1657730522414786219, "updated_time": 1657740457514039961, "inserted_size": 0, "status_reason": 0, "mid": "2788e63efeb54cadbfc1a106c9faffe3", "size": 0, "timestamp": 1657740457514039961, "is_ask": false, "inserted_price": 0}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 203, "open_interest": 835, "filled_size": 0, "is_volatile": true, "clock": 119341, "original_size": 152, "price": 0, "vwap": 0, "type": "action_report", "original_price": 38100, "ticks": 1657740457514039961, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 152, "contract_id": 22244140, "inserted_time": 1657730522414786219, "updated_time": 1657740457514039961, "inserted_size": 0, "status_reason": 0, "mid": "2788e63efeb54cadbfc1a106c9faffe3", "size": 0, "timestamp": 1657740457514039961, "is_ask": false, "inserted_price": 0}'
# ++Rcv raw: b'\x81~\x02B{"status_type": 200, "open_interest": 835, "filled_size": 0, "is_volatile": true, "clock": 119342, "original_size": 152, "price": 35100, "vwap": 0, "type": "action_report", "original_price": 35100, "ticks": 1657740457514039962, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22244140, "inserted_time": 1657730522414786219, "updated_time": 1657740457514039961, "inserted_size": 152, "status_reason": 0, "mid": "2788e63efeb54cadbfc1a106c9faffe3", "size": 152, "timestamp": 1657740457514039961, "is_ask": false, "inserted_price": 35100}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"status_type": 200, "open_interest": 835, "filled_size": 0, "is_volatile": true, "clock": 119342, "original_size": 152, "price": 35100, "vwap": 0, "type": "action_report", "original_price": 35100, "ticks": 1657740457514039962, "filled_price": 0, "order_type": "customer_limit_order", "canceled_size": 0, "contract_id": 22244140, "inserted_time": 1657730522414786219, "updated_time": 1657740457514039961, "inserted_size": 152, "status_reason": 0, "mid": "2788e63efeb54cadbfc1a106c9faffe3", "size": 152, "timestamp": 1657740457514039961, "is_ask": false, "inserted_price": 35100}'
# ++Rcv raw: b'\x81~\x00\x90{"bid": 4901700, "ask_size": 1, "bid_size": 75, "type": "book_top", "clock": 97707, "contract_type": 1, "ask": 5064500, "contract_id": 22241076}'
# ++Rcv decoded: fin=1 opcode=1 data=b'{"bid": 4901700, "ask_size": 1, "bid_size": 75, "type": "book_top", "clock": 97707, "contract_type": 1, "ask": 5064500, "contract_id": 22241076}'
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
# JSON MESSAGE FOR YA
